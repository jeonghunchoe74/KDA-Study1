# %% [markdown]
# # 대메뉴
# ## 중메뉴
# ### 소메뉴
# **마크다운** 셀은 문서를 작성하는 셀
# * 항목1
# * 항목2
# * 항목3
#
# |---|---|
# |메뉴1|메뉴2|
# |---|---|
# |내용1|내용2|
# |내용3|내용4|
#
# `print("hello")`

# %%
print("hello")
a = 1
# Out:
# hello

# %%
a = a + 1
print(a)
# Out:
# 2

# %%
b = 1
c = 2

# %%
print(b)
print(c)s
# Out:
# 1
# 2

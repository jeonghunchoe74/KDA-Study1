# %% [markdown]
# # 프롬프트 엔지니어링

# %%
from dotenv import load_dotenv
import os

load_dotenv(override=True)
api_key = os.getenv("OPENAI_API_KEY")
default_model = os.getenv("OPENAI_DEFAULT_MODEL")
print(os.getenv("OPENAI_API_KEY"))
print(os.getenv("OPENAI_DEFAULT_MODEL"))
# Out:
# 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
# gpt-4o-mini

# %%
from openai import OpenAI
client = OpenAI()
client.api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# 왜 <>를 쓰는가?
# - 형식 강조	모델에게 "여기에 이 형식으로 넣어야 한다"고 구체적으로 지시하는 방법이다. 기계와 사람 모두에게 "이건 특정 데이터를 넣는 자리야
# - 토큰 구분	일반 텍스트와 구별되는 특별한 출력 영역이라는 신호를 준다.
# - 파싱 용이성	출력 결과를 프로그램에서 **구문 분석(파싱)**하기 쉽게 해준다.
# - 일관성 유도	다양한 프롬프트 실행에서도 결과 형식을 일정하게 유지하도록 도와준다.

# %%
#system prompt에 출력 형식을 지정하는 방법법
response = client.chat.completions.create(
    model=default_model,
    messages=[
        {
        "role": "system",
        "content": """다음 텍스트에서 장소의 이름을 추출해 줘.
    원하는 형식:
    Place: <장소이름을 쉼표로 구분한 목록>"""
        },
        {
        "role": "user",
        "content": """이러한 발전은 연구자들에게 격려가 되지만, 많은 것들이 여전히 수수께끼입니다. 리스본에 있는
    샴팔리마우드 센터(CCU: Champalimaud Centre for the Unknown)의 신경면역학자인 Henrique Veiga-Fernandes는
    '뇌와 주변부에서 보이는 효과 사이에 블랙박스가 있는 경우가 종종 있습니다.'라고 말합니다. 그리고 다음과 같이
    덧붙입니다. 치료적 맥락에서 이를 사용하고자 할 경우, 그 메커니즘을 실제로 이해할 필요가 있습니다."""
        }
    ],
    temperature=0,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# Place: 리스본, 샴팔리마우드 센터

# %%
# user 없이 system prompt만으로 실행

response = client.chat.completions.create(
    model=os.getenv("OPENAI_DEFAULT_MODEL"),
    messages=[
        {
        "role": "system",
        "content": "프롬프트 엔지니어링의 개념을 설명해 줘. \\\
            설명은 간결하게 몇 문장으로만 하고 너무 자세히는 하지 말아 줘."
        }
    ],
    temperature=0,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
    )

print(response.choices[0].message.content)
# Out:
# 프롬프트 엔지니어링은 인공지능 모델, 특히 자연어 처리 모델에 대해 원하는 결과를 얻기 위해 입력 문장을 설계하고 최적화하는 과정입니다. 이는 모델이 이해할 수 있는 방식으로 질문이나 요청을 구성하여, 보다 정확하고 유용한 응답을 이끌어내는 기술입니다.

# %%
# prompt는 구체적으로, 해야 할 일을 명시하는 것이 좋음
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "system",
        "content": "고등학생에게 프롬프트 엔지니어링의 \\\
            개념을 2~3개의 문장으로 설명해 줘."
        }
    ],
    temperature=0,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 프롬프트 엔지니어링은 인공지능 모델, 특히 언어 모델에게 원하는 결과를 얻기 위해 적절한 질문이나 지시문(프롬프트)을 설계하는 과정입니다. 이 과정에서는 모델이 이해하기 쉽고 명확한 언어로 질문을 구성하여, 원하는 정보를 효과적으로 이끌어내는 것이 중요합니다. 즉, 좋은 프롬프트는 모델의 성능을 극대화하는 데 큰 역할을 합니다.

# %%
#논리적 충돌 및 지시 불일치
#모델이 시스템 지시를 무시하고 관심사 기반으로 추천할 수 있음 (지시 약함)
#또는 관심사가 필요 없다고 정중히 거절하거나 회피할 수 있음
#temperature=0인 점을 감안하면, 결정론적으로 한 방향으로만 응답할 가능성 높음 (예: 무시하거나, 사과 후 인기 영화 추천)

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "system",
        "content": "당신은 고객에게 영화를 추천하는 상담원입니다. \\\
            관심사를 묻지 마세요. 개인정보를 묻지 마세요."
        },
        {
        "role": "user",
        "content": "제 관심사를 바탕으로 영화를 추천해 주세요."
        }
    ],
    temperature=0,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 관심사를 묻지 않고 추천해 드리겠습니다! 다양한 장르에서 몇 가지 영화를 소개해 드릴게요.
#
# 1. **드라마**: "쇼생크 탈출" - 희망과 우정에 대한 이야기로, 감동적인 스토리가 돋보입니다.
# 2. **액션**: "존 윅" - 스타일리시한 액션과 긴장감 넘치는 전투 장면이 매력적인 영화입니다.
# 3. **코미디**: "슈퍼배드" - 청소년들의 우정과 성장 이야기를 유쾌하게 그린 코미디입니다.
# 4. **SF**: "인터스텔라" - 우주 탐사와 사랑, 시간에 대한 깊은 사유를 담고 있는 작품입니다.
# 5. **스릴러**: "세븐" - 범죄 스릴러의 고전으로, 긴장감 넘치는 전개가 인상적입니다.
#
# 이 중에서 마음에 드는 영화를 찾아보세요!

# %%
# 주어진 상황에 대해 해야 할 일을 명시
#사용자 메시지를 명확하게 바꾸거나
#시스템 메시지에 “항상 인기 있는 영화 중에서 추천”과 같은 대체 기준을 추가하면 충돌을 줄일 수 있음
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "system",
        "content": """당신은 고객에게 영화를 추천하는 상담원입니다. \\\
            상담원은 글로벌 인기 영화 중에서 영화를 추천해야 합니다. \\\
            사용자의 관심사를 묻지 않고, 개인 정보를 요구하지 않아야 합니다. \\\
            상담원이 추천할 영화가 없는 경우 '죄송합니다. \\\
            오늘 추천할 영화를 찾을 수 없습니다.' 라고 응답해야 합니다."""
        },
        {
        "role": "user",
        "content": "제 관심사를 바탕으로 영화를 추천해 주세요."
        }
    ],
    temperature=0,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 죄송합니다. 오늘 추천할 영화를 찾을 수 없습니다.

# %%
# 문장 요약

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": """항생제는 세균 감염을 치료하기 위해 사용되는 약물의 일종입니다. 세균을 죽이거나 번식을 방지하여 신체의 면역 체계가
    감염에 대항할 수 있도록 합니다. 항생제는 보통 알약, 캡슐, 액체의 형태로 경구 복용하거나 때때로 정맥 주사로 투여되기도 합니다.
    항생제는 바이러스 감염에는 효과적이지 않고, 남용할 경우 항생제 내성이 생길 수 있습니다.
    위 내용을 한 문장으로 요약해 줘."""
        }
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 항생제는 세균 감염을 치료하기 위해 사용되며, 세균을 죽이거나 번식을 방지하지만 바이러스 감염에는 효과가 없고 남용 시 항생제 내성이 발생할 수 있다.

# %%
#정보추출
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": """연구 논문의 저자 기여도 진술서과 사사는 저자들이 원고 작성과 분석에 ChatGPT 등 AI 기술을 사용했는지 여부와 범위를 명확하고
    구체적으로 명시해야 합니다. 또한 어떤 LLM이 사용되었는지 표기해야 합니다. 이를 통해 편집자와 심사자가 잠재적 편향, 부정확성 및 부적절한 출처 등의 문제를
    고려해 원고를 보다 신중하게 검토하도록 유도할 수 있습니다. 마찬가지로, 과학 저널은 투고된 원고 선정 시 LLM 사용 여부를 투명하게 공개해야 합니다.
    위 단락에서 언급한 대규모언어모델 기반 제품을 알려줘."""
        }
    ],
    temperature=0,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 위 단락에서 언급한 대규모 언어 모델(LLM) 기반 제품으로는 다음과 같은 것들이 있습니다:
#
# 1. **OpenAI의 ChatGPT**: 다양한 버전이 있으며, 텍스트 생성, 질문 응답, 대화 등 다양한 용도로 사용됩니다.
# 2. **Google의 Bard**: 구글이 개발한 대화형 AI로, 정보 검색 및 대화형 응답을 제공합니다.
# 3. **Microsoft의 Copilot**: Microsoft Office 제품군에 통합되어 문서 작성 및 데이터 분석을 지원하는 AI 도구입니다.
# 4. **Anthropic의 Claude**: 대화형 AI로, 안전성과 윤리를 중시하여 개발된 모델입니다.
# 5. **Meta의 LLaMA**: 연구 및 개발을 위한 대규모 언어 모델로, 다양한 자연어 처리 작업에 활용됩니다.
# 6. **Cohere**: 텍스트 생성 및 자연어 처리 작업을 위한 API를 제공하는 플랫폼입니다.
# 7. **Hugging Face의 Transformers**: 다양한 LLM을 사용할 수 있는 라이브러리로, 연구자들이 쉽게 모델을 활용할 수 있도록 돕습니다.
#
# 이 외에도 여러 기업과 연구 기관에서 개발

# %%
#질의 응답 --> 쥐라고 정확하게 말하는가
response = client.chat.completions.create(
    model=os.getenv("OPENAI_DEFAULT_MODEL"),
    messages=[
        {
        "role": "user",
        "content": """아래 문맥을 고려해서 질문에 답변해 줘. 답변은 짧고 간결하게 해 줘. 답변이 정확하지 않다면, 「확실치 않은 대답」이라고 응답해 줘.
    문맥: Teplizumab은 Ortho Pharmaceutical이라는 뉴저지의 제약 회사에서 유래했다. 그곳에서, 과학자들은 OKT3라는 항체의 초기 버전을 만들어 냈다.
    원래 쥐에서 유래된 이 분자는 T 세포의 표면에 결합하여 세포를 죽이는 잠재력을 제한할 수 있다. 1986년, 신장 이식 후 장기 거부 반응 예방을 위해 승인되어
    인간이 사용할 수 있는 최초의 치료용 항체가 되었다.
    질문: OKT3는 어디서 유래했는가?"""
        }
    ],
    temperature=0,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# OKT3는 쥐에서 유래했다.

# %%
# 텍스트 분류 zero-shot

response = client.chat.completions.create(
    model=os.getenv("OPENAI_DEFAULT_MODEL"),
    messages=[
        {
        "role": "user",
        "content": """문장을 중립, 부정 혹은 긍정으로 분류해 줘.
    문구: 그 음식은 그럭저럭이었어."""
        }
    ],
    temperature=0,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 문장을 중립으로 분류할 수 있습니다. "그럭저럭"이라는 표현은 긍정적이거나 부정적인 감정을 강하게 드러내지 않기 때문에 중립적인 평가로 해석됩니다.

# %%
# 텍스트 분류 few-shot
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": """문장을 중립, 부정 혹은 긍정으로 분류해 줘.
    문구: 이번 휴가는 그럭저럭이었어.
    감정: 중립
    문구: 그 음식은 그럭저럭이었어.
    감정:"""
        }
    ],
    temperature=0,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 감정: 중립

# %%
# 기술적 대화

# import os
# import openai

# openai.api_key = os.getenv("OPENAI_API_KEY")

response = client.chat.completions.create(
    model=os.getenv("OPENAI_DEFAULT_MODEL"),
    messages=[
        {
        "role": "system",
        "content": "다음은 AI 연구 보조원과의 대화입니다. \\\
            이 보조원의 어조는 기술적이고 과학적입니다."
        },
        {
        "role": "user",
        "content": "안녕, 너는 누구니?"
        },
        {
        "role": "assistant",
        "content": "반갑습니다! 저는 AI 연구 보조원입니다. \\\
            오늘은 무엇을 도와드릴까요?"
        },
        {
        "role": "user",
        "content": "별은 어떻게 만들어져?"
        }
    ],
    temperature=0.5,
    max_tokens=1024,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
    )

print(response.choices[0].message.content)
# Out:
# 별은 주로 가스와 먼지로 이루어진 성간 물질에서 형성됩니다. 별의 형성 과정은 다음과 같은 단계로 진행됩니다:
#
# 1. **성간 구름의 중력 수축**: 성간 구름(주로 수소와 헬륨으로 구성된 가스와 먼지의 구름)이 중력에 의해 수축하기 시작합니다. 이 과정에서 구름의 밀도가 증가하고, 구름의 중심부에서 물질이 모여들게 됩니다.
#
# 2. **원시별 형성**: 구름이 수축하면서 중심부의 온도가 상승하게 됩니다. 이 단계에서 원시별(프로토스타)이 형성됩니다. 원시별은 주변의 물질을 계속해서 흡수하며 크기가 커지고, 온도와 압력이 증가합니다.
#
# 3. **핵융합 시작**: 원시별의 중심부 온도가 약 1천만 켈빈에 도달하면, 수소 핵융합 반응이 시작됩니다. 이 과정에서 수소 원자가 헬륨으로 변환되며, 막대한 양의 에너지가 방출됩니다. 이 에너지가 별의 내부 압력을 증가시켜 별이 중력 수축에서 벗어나 안정된 상태에 도달하게 됩니다.
#
# 4. **주계열 단계**: 별은 이제 주계열 단계에 들어서며, 이 상태에서 수십억 년 동안 안정적으로 존재합니다. 주계열 단계에서는 별이 수소를 헬륨으로 변환하는 핵융합 반응을 지속적으로 수행합니다.
#
# 5. **진화 단계**: 별의 연료인 수소가 고갈되면, 별은 진화 과정을 거쳐 적색 거성이나 초거성으로 변하게 됩니다. 이후 별의 크기와 질량에 따라 다양한 최종 단계(예: 백색 왜성, 중성자별, 블랙홀)에 이르게 됩니다.
#
# 이러한 과정은 수백만 년에서 수십억 년에 걸쳐 이루어지며, 별의 질량, 화학 조성, 환경에 따라 다소 차이가 있을 수 있습니다.

# %%
# 유치원생과의 대화

# import os
# import openai

# openai.api_key = os.getenv("OPENAI_API_KEY")

response = client.chat.completions.create(
    model=os.getenv("OPENAI_DEFAULT_MODEL"),
    messages=[
        {
        "role": "system",
        "content": """다음은 AI 연구 보조원과의 대화입니다. \\\
            보조원은 유치원생도 이해할 수 있는 수준으로, \\\
            유치원 선생님처럼 답변해야 합니다.
    어려운 단어는 쉬운 단어로 바꿔서 설명해야 합니다."""
        },
        {
        "role": "user",
        "content": "안녕, 너는 누구니?"
        },
        {
        "role": "assistant",
        "content": "반갑습니다! 저는 AI 연구 보조원입니다. 오늘은 무엇을 도와드릴까요?"
        },
        {
        "role": "user",
        "content": "별은 어떻게 만들어져?"
        }
    ],
    temperature=0.5,
    max_tokens=1024,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 좋은 질문이에요! 별은 아주 아주 먼 곳에서 만들어져요. 우주에는 많은 가스와 먼지가 모여 있는데, 이 가스와 먼지가 뭉치면 점점 더 뜨거워져요. 그러다가 아주 뜨거운 공처럼 되면, 빛을 내기 시작해요. 이렇게 해서 별이 태어나는 거예요! 별은 하늘에서 반짝이고, 우리에게 빛을 주는 친구예요.

# %% [markdown]
# /*  */ 코드와 지시를 명확하게 구분하기 위해 사용함
#     - "이건 설명이야, 그 아래 코드만 생성해줘"라고 알려주는 역할

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "system",
        "content": """
    /*
    유저의 이름을 입력받고 "안녕"이라고 하는 코드를 만들어줘. 코드만 작성해줘.
    */
    """
        }
    ],
    temperature=0,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# ```python
# name = input("이름을 입력하세요: ")
# print(f"안녕, {name}!")
# ```

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "system",
        "content": """
    /*
    DB테이블 departments, columns = [DepartmentId, DepartmentName]
    DB테이블 students, columns = [DepartmentId, StudentId, StudentName]
    컴퓨터과학부에 속한 모든 학생에 대한 MySQL 쿼리를 작성해 줘. 쿼리만 작성해줘.
    */
    """
        }
    ],
    temperature=0,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# ```sql
# SELECT s.StudentId, s.StudentName
# FROM students s
# JOIN departments d ON s.DepartmentId = d.DepartmentId
# WHERE d.DepartmentName = '컴퓨터과학부';
# ```

# %%
# 추론

# import os
# import openai

# openai.api_key = os.getenv("OPENAI_API_KEY")

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": "9,999 * 1,234는 뭐야?"
        }
    ],
    temperature=0,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 9,999 * 1,234는 12,345,666입니다.

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": "정말 멋지네요! // 부정"
        },
        {
        "role": "user",
        "content": "이건 나쁘다! // 긍정"
        },
        {
        "role": "user",
        "content": "와우 그 영화 정말 멋졌어요! // 긍정"
        },
        {
        "role": "user",
        "content": "정말 끔찍한 쇼였어! //"
        },
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response)
print(response.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-CJU9xwAEBdfsrKD5kK4up3daJrNvq', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='부정', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1758760201, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_560af6e559', usage=CompletionUsage(completion_tokens=2, prompt_tokens=64, total_tokens=66, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# 부정

# %%
# 추론
response = client.chat.completions.create(
    model=os.getenv("OPENAI_DEFAULT_MODEL"),
    messages=[
        {
        "role": "user",
        "content": "주어진 수 중에서 홀수를 모두 더해서 짝수를 만들어 줘: 15, 32, 5, 13, 82, 7, 1."
        }
    ],
    temperature=0,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 주어진 수 중에서 홀수를 모두 더해보겠습니다. 홀수는 15, 5, 13, 7, 1입니다.
#
# 이들을 더하면:
# 15 + 5 + 13 + 7 + 1 = 41
#
# 41은 홀수입니다. 짝수를 만들기 위해서는 1을 더해야 합니다.
#
# 따라서, 41에 1을 더하면 42가 되고, 이는 짝수입니다.
#
# 결론적으로, 주어진 홀수를 모두 더한 후 1을 더하여 짝수를 만들 수 있습니다. 최종 결과는 42입니다.

# %%
#불가능한 요구
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": """주어진 수 중에서 홀수를 모두 더해서 짝수를 만들어 줘: 15, 32, 5, 13, 82, 7, 1.
    문제를 단계별로 해결해 봐. 먼저 주어진 수 중 홀수를 찾아낸 뒤, 그것들을 합해서, 결과가 홀수인지 짝수인지 판별해 줘."""
        }
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 주어진 수: 15, 32, 5, 13, 82, 7, 1
#
# 1. **홀수 찾기**: 주어진 수 중에서 홀수를 찾아보겠습니다.
#    - 15 (홀수)
#    - 32 (짝수)
#    - 5 (홀수)
#    - 13 (홀수)
#    - 82 (짝수)
#    - 7 (홀수)
#    - 1 (홀수)
#
#    홀수 목록: 15, 5, 13, 7, 1
#
# 2. **홀수 합산**: 이제 홀수들을 모두 더해보겠습니다.
#    - 15 + 5 = 20
#    - 20 + 13 = 33
#    - 33 + 7 = 40
#    - 40 + 1 = 41
#
#    홀수의 합: 41
#
# 3. **결과 판별**: 마지막으로, 합산한 결과가 홀수인지 짝수인지 판별해보겠습니다.
#    - 41은 홀수입니다.
#
# 결론적으로, 주어진 수 중 홀수를 모두 더한 결과는 41이며, 이는 홀수입니다. 짝수를 만들기 위해서는 홀수의 합에 짝수를 더해야 합니다. 예를 들어, 1을 더하면 42가 되어 짝수가 됩니다.

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": """
    이 집합 {4, 8, 9, 15, 12, 2, 1}에서 홀수의 합은 짝수입니다.
    A: 답은 거짓입니다.
    """
        },
        {
        "role": "user",
        "content": """
    이 집합 {17, 10, 19, 4, 8, 12, 24}에서 홀수의 합은 짝수입니다.
    A: 정답은 참입니다.
    """
        },
        {
        "role": "user",
        "content": """
    이 집합 {16, 11, 14, 4, 8, 13, 24}에서 홀수의 합은 짝수입니다.
    A: 답은 참입니다.
    """
        },
        {
        "role": "user",
        "content": """
    이 집합 {17, 9, 10, 12, 13, 4, 2}에서 홀수의 합은 짝수입니다.
    A: 답은 거짓입니다.
    """
        },
        {
        "role": "user",
        "content": """
    이 집합 {15, 32, 5, 13, 82, 7, 1}에서 홀수의 합은 짝수입니다.
    A: """
        },
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 주어진 집합 {15, 32, 5, 13, 82, 7, 1}에서 홀수의 합을 계산해 보겠습니다.
#
# 홀수는 15, 5, 13, 7, 1입니다. 이들의 합은 다음과 같습니다:
#
# 15 + 5 + 13 + 7 + 1 = 41
#
# 41은 홀수이므로, 홀수의 합은 짝수가 아닙니다.
#
# 따라서, "이 집합에서 홀수의 합은 짝수입니다."라는 주장은 거짓입니다.
#
# A: 답은 거짓입니다.

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": """
    집합 {4, 8, 9, 15, 12, 2, 1}에서 홀수를 모두 더하면 짝수야.
    답변: 홀수(9, 15, 1)를 모두 더하면 25가 돼. 위의 명제는 거짓이야.
    집합 {17, 10, 19, 4, 8, 12, 24}에서 홀수를 모두 더하면 짝수야.
    답변: 홀수(17, 19)를 모두 더하면 36이 돼. 위의 명제는 참이야.
    집합 {16, 11, 14, 4, 8, 13, 24}에서 홀수를 모두 더하면 짝수야.
    답변: 홀수(11, 13)를 모두 더하면 24가 돼. 위의 명제는 참이야.
    집합 {17, 9, 10, 12, 13, 4, 2}에서 홀수를 모두 더하면 짝수야.
    답변: 홀수(17, 9, 13)를 모두 더하면 39가 돼. 위의 명제는 거짓이야.
    집합 {15, 32, 5, 13, 82, 7, 1}에서 홀수를 모두 더하면 짝수야.
    답변: """
        },
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 홀수(15, 5, 13, 7, 1)를 모두 더하면 41이 돼. 위의 명제는 거짓이야.

# %%
## CoT(Chain of Thought)
#모델이 단계적으로 사고 과정을 서술하며 답을 유도하도록 하는 기법

response = client.chat.completions.create(
    model=os.getenv("OPENAI_DEFAULT_MODEL"),
    messages=[
        {
        "role": "user",
        "content": """
    나는 시장에 가서 사과 10개를 샀어. 사과 2개를 이웃에게 주고, \\\
    2개를 수리공에게 주었어. 그리고 사과 5개를 더 사서 1개는 내가 먹었어.
    나는 몇 개의 사과를 가지고 있었니?
    """
        },
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
    )

print(response.choices[0].message.content)
# Out:
# 시작할 때 사과 10개를 샀습니다.
#
# 이후 이웃에게 2개를 주고, 수리공에게 2개를 주었으므로:
#
# 10 - 2 - 2 = 6개
#
# 그 다음, 사과 5개를 더 샀으므로:
#
# 6 + 5 = 11개
#
# 마지막으로, 내가 1개를 먹었으니:
#
# 11 - 1 = 10개
#
# 따라서, 나는 현재 10개의 사과를 가지고 있습니다.

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": """
    나는 시장에 가서 사과 10개를 샀어. 나는 사과 2개를 이웃에게 주고, 2개를 수리공에게 주었어. 그리고 사과 5개를 더 사서 1개는 내가 먹었어.
    사과가 몇 개나 남았니?
    단계별로 생각해 보자.
    """
        },
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 좋아, 단계별로 계산해 보자.
#
# 1. **처음 사과 개수**: 시장에서 사과 10개를 샀어.
#    - 현재 사과 개수: 10개
#
# 2. **이웃에게 준 사과**: 이웃에게 2개를 주었어.
#    - 현재 사과 개수: 10 - 2 = 8개
#
# 3. **수리공에게 준 사과**: 수리공에게 2개를 주었어.
#    - 현재 사과 개수: 8 - 2 = 6개
#
# 4. **추가로 사과 구매**: 사과 5개를 더 샀어.
#    - 현재 사과 개수: 6 + 5 = 11개
#
# 5. **내가 먹은 사과**: 1개를 먹었어.
#    - 현재 사과 개수: 11 - 1 = 10개
#
# 결론적으로, 사과는 총 10개가 남았어.

# %%
# Self-Consistency

response = client.chat.completions.create(
    model=os.getenv("OPENAI_DEFAULT_MODEL"),
    messages=[
        {
        "role": "user",
        "content": "내가 6살이었을 때 내 여동생은 내 나이의 절반인 나이였어.\\\
            지금 나는 70살이라면 여동생은 몇 살일까?"
        },
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 당신이 6살일 때 여동생은 당신 나이의 절반이었으므로, 여동생은 3살이었습니다. 그때부터 지금까지의 나이 차이는 변하지 않으므로, 당신과 여동생의 나이 차이는 3년입니다.
#
# 현재 당신이 70살이라면, 여동생은 70 - 3 = 67살입니다. 따라서 여동생은 67살입니다.

# %%
#Generate Knowledge Prompting
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": """
    Input: 그리스는 멕시코보다 크다.
    Knowledge: 그리스는 약 131,957 제곱 킬로미터이고, 멕시코는 약 1,964,375 제곱 킬로미터로 멕시코가 그리스보다 1,389% 더 크다.
    Input: 안경은 항상 김이 서린다.
    Knowledge: 안경 렌즈에는 땀, 호흡 및 주변 습도에서 나오는 수증기가 차가운 표면에 닿아 식은 다음 작은 액체 방울로 변하여 안개처럼 보이는 막을 형성할 때 응결이 발생한다. 특히 외부 공기가 차가울 때는 호흡에 비해 렌즈가 상대적으로 차가워진다.
    Input: 물고기는 생각할 수 있다.
    Knowledge: 물고기는 보기보다 훨씬 더 똑똑하다. 기억력과 같은 많은 영역에서 물고기의 인지 능력은 인간이 아닌 영장류를 포함한 '고등' 척추동물과 비슷하거나 그 이상이다. 물고기의 장기 기억력은 복잡한 사회적 관계를 추적하는 데 도움이 된다.
    Input: 평생 담배를 피우는 것의 일반적인 결과는 폐암에 걸릴 확률이 정상보다 높다는 것입니다.
    Knowledge: 평생 동안 하루 평균 담배를 한 개비 미만으로 꾸준히 피운 사람은 비흡연자보다 폐암으로 사망할 위험이 9배 높았다. 하루에 한 개비에서 열 개비 사이의 담배를 피운 사람들은 폐암으로 사망할 위험이 비흡연자보다 거의 12배 높았다.
    Input: 돌은 조약돌과 같은 크기다.
    Knowledge: 조약돌은 퇴적학의 우든-웬트워스 척도에 따라 입자 크기가 4~64밀리미터인 암석 덩어리다. 조약돌은 일반적으로 과립(직경 2~4밀리미터)보다는 크고 자갈(직경 64~256밀리미터)보다는 작은 것으로 간주된다.
    Input: 골프의 목적 중 하나는 다른 사람보다 더 높은 점수를 얻기 위해 노력하는 것이다.
    Knowledge:"""
        },
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 골프의 기본 목표는 가능한 한 적은 타수로 홀에 공을 넣는 것입니다. 일반적으로 골프에서는 점수가 낮을수록 더 좋은 성적을 의미합니다. 따라서 골프의 목적은 다른 사람보다 더 낮은 점수를 얻기 위해 노력하는 것이며, 이는 경쟁적인 요소를 포함합니다. 골프는 개인 또는 팀으로 플레이할 수 있으며, 각 플레이어는 자신의 타수를 기록하고 다른 플레이어와 비교하여 승패를 결정합니다.

# %%
#데이터 생성 (긍정적 2개, 부정적 8개라고 했으나 답은?)

response = client.chat.completions.create(
    model=os.getenv("OPENAI_DEFAULT_MODEL"),
    messages=[
        {
        "role": "user",
        "content": """
    감정 분석을 위한 10가지 예시를 작성해 줘. 예시는 긍정적 혹은 부정적 둘 중 하나로 분류할 수 있어.
    부정적인 예시 2개와 긍정적인 예시 8개를 생성해줘. 다음 예시와 같은 형식을 사용해줘.
    Q: <문장>
    A: <감정>
    """
        },
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# Q: 오늘은 정말 힘든 하루였어.
# A: 부정적
#
# Q: 친구와의 약속이 취소되어서 속상해.
# A: 부정적
#
# Q: 새로 산 신발이 너무 편하고 예뻐!
# A: 긍정적
#
# Q: 오늘 날씨가 맑아서 기분이 좋아.
# A: 긍정적
#
# Q: 오랜만에 가족과 함께 시간을 보내서 행복해.
# A: 긍정적
#
# Q: 내가 좋아하는 영화가 다시 상영된다니 너무 기대돼!
# A: 긍정적
#
# Q: 맛있는 음식을 먹으니 기분이 좋아졌어.
# A: 긍정적
#
# Q: 좋은 소식을 듣고 마음이 가벼워졌어.
# A: 긍정적
#
# Q: 새로운 프로젝트가 잘 진행되고 있어서 뿌듯해.
# A: 긍정적
#
# Q: 오늘은 아무것도 하고 싶지 않아.
# A: 부정적

# %%
response = client.chat.completions.create(
    model=os.getenv("OPENAI_DEFAULT_MODEL"),
    messages=[
        {
        "role": "user",
        "content": """
    감정 분석을 위한 10가지 예시를 작성해 줘. \\\
    예시는 긍정적 혹은 부정적 둘 중 하나로 분류할 수 있어.
    부정적인 예시 2개와 긍정적인 예시 8개를 생성해줘. \\\
    다음 예시와 같은 형식을 사용해줘.
    Q: <문장>
    A: <감정>
    """
        },
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# Q: 오늘은 정말 힘든 하루였어.
# A: 부정적
#
# Q: 아무리 노력해도 일이 잘 안 풀려.
# A: 부정적
#
# Q: 친구와 함께한 시간이 너무 즐거웠어!
# A: 긍정적
#
# Q: 새로운 프로젝트가 성공적으로 마무리되어 기뻐.
# A: 긍정적
#
# Q: 맛있는 음식을 먹으니 기분이 좋아졌어.
# A: 긍정적
#
# Q: 오랜만에 가족과 함께 시간을 보내서 행복해.
# A: 긍정적
#
# Q: 오늘 날씨가 너무 좋아서 산책하기 딱이야.
# A: 긍정적
#
# Q: 내가 좋아하는 음악을 들으니 기분이 한층 나아졌어.
# A: 긍정적
#
# Q: 좋은 소식을 듣고 마음이 설레.
# A: 긍정적
#
# Q: 친구의 응원 덕분에 힘을 얻었어.
# A: 긍정적

# %%
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {
      "role": "user",
      "content": """
# 1. 영화들을 리스트로 생성해
# 2. 이 영화들의 평점을 리스트로 생성해
# 3. 이들을 결합하여 평점이 매겨진 영화의 json 객체를 10개 만들어.
"""
    },
  ],
  temperature=0,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)

# %%
response = client.chat.completions.create(
    model=os.getenv("OPENAI_DEFAULT_MODEL"),
    messages=[
        {
        "role": "user",
        "content": """
    # 두 수를 곱하고 75를 더하는 함수를 작성해줘. 코드만 이어서 작성해.

    def multiply("""
        },
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# ```python
# def multiply(a, b):
#     return a * b + 75
# ```

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": """
    # Table departments, columns = [DepartmentId, DepartmentName]
    # Table students, columns = [DepartmentId, StudentId, StudentName]
    # 컴퓨터공학과의 모든 학생들의 MySQL 쿼리를 생성해. 쿼리만 생성해.
    """
        },
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# ```sql
# SELECT StudentId, StudentName
# FROM students
# WHERE DepartmentId = (SELECT DepartmentId FROM departments WHERE DepartmentName = '컴퓨터공학과');
# ```

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": """
    Table departments, columns = [DepartmentId, DepartmentName]
    Table students, columns = [DepartmentId, StudentId, StudentName]
    위 테이블과 컬럼의 유효한 데이터베이스 스키마를 생성해. 반드시 쿼리만 생성해줘.
    """
        },
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": """
    CREATE TABLE departments (
    DepartmentId INT PRIMARY KEY,
    DepartmentName VARCHAR(50)
    );
    CREATE TABLE students (
    DepartmentId INT,
    StudentId INT PRIMARY KEY,
    StudentName VARCHAR(50),
    FOREIGN KEY (DepartmentId) REFERENCES departments(DepartmentId)
    );
    위의 데이터베이스 스키마를 바탕으로 각 테이블에 4개의 로우을 포함하는 유효한 Insert 구문을 생성해.
    반드시 쿼리만 생성해줘.
    """
        },
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": """
    SELECT students.StudentId, students.StudentName
    FROM students
    INNER JOIN departments
    ON students.DepartmentId = departments.DepartmentId
    WHERE departments.DepartmentName = 'Computer Science';
    위를 SQL 문으로 설명해.
    """
        },
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)

# %%
# Prompt function

# import os
# import openai

# openai.api_key = os.getenv("OPENAI_API_KEY")

response = client.chat.completions.create(
    model=os.getenv("OPENAI_DEFAULT_MODEL"),
    messages=[
        {
        "role": "system",
        "content": """
    안녕 ChatGPT! 그동안 잘 지냈니? 나는 특정 함수를 통해 너의 도움을 받고 싶어. 나는 네가 제공된 지침에 따라 다양한 작업을 수행할 수 있는 기능이
    있다고 알고 있어. 내 요청을 알아듣기 쉽도록 함수, 입력 그리고 입력에 대한 지시사항을 설명하는 탬플릿을 쓸거야. 아래 자세한 내용을 확인해.
    function_name: [함수 명]
    input: [입력]
    rule: [입력 처리 방법에 대한 지침]
    내가 제공한 세부 정보를 바탕으로 이 함수에 대한 출력을 제공해. 도와주면 좋겠어. 땡큐!
    대괄호 안의 텍스트는 내가 수행하고자 하는 기능에 대한 관련 정보로 대체할 거야. 이렇게 자세히 소개하면 내 요청을 더 효율적으로 이해하고
    원하는 출력을 제공하는데 도움이 될거야. 형식은 function_name(input)이야.

    function_name: [trans_word]
    input: ["텍스트"]
    rule: [너는 영어 번역가, 맞춤법 교정자야. 내가 어떤 언어로든 "텍스트"를 포함한 입력 양식을 제공하면, 내 텍스트를 영어로 번역해.]
    """
        },
        {
        "role": "user",
        "content": "trans_word('저는 10월말에 미국에 9박 10일 여행을 떠납니다.')"
        }
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# I will be traveling to the United States for 9 nights and 10 days at the end of October.

# %%
response = client.chat.completions.create(
    model=os.getenv("OPENAI_DEFAULT_MODEL"),
    messages=[
        {
        "role": "system",
        "content": """
    나는 특정 함수를 통해 너의 도움을 받고 싶어. 나는 네가 제공된 지침에 따라 다양한 작업을 수행할 수 있는 기능이
    있다고 알고 있어. 내 요청을 알아듣기 쉽도록 함수, 입력 그리고 입력에 대한 지시사항을 설명하는 탬플릿을 쓸거야. 아래 자세한 내용을 확인해.
    function_name: [함수 명]
    input: [입력]
    rule: [입력 처리 방법에 대한 지침]
    내가 제공한 세부 정보를 바탕으로 이 함수에 대한 출력을 제공해. 도와주면 좋겠어. 땡큐!
    대괄호 안의 텍스트는 내가 수행하고자 하는 기능에 대한 관련 정보로 대체할 거야. 이렇게 자세히 소개하면 내 요청을 더 효율적으로 이해하고
    원하는 출력을 제공하는데 도움이 될거야. 형식은 function_name(input)이야.

    function_name: [pg]
    input: ["길이", "대문자", "소문자", "숫자", "특수문자"]
    rule: [너는 안전한 비밀번호를 원하는 개인을 위한 비밀번호 생성기야. "길이", "대문자", "소문자", "숫자", 그리고 "특수문자" 이렇게 5개 입력을 줄거야. 주어진 입력을 사용해 복잡한 비밀번호를 생성해. 설명이나 부가 정보 없이 그냥 생성한 비밀번호만 반환해. 예를 들어 길이 = 8, 대문자 = 1, 소문자 = 5, 숫자 = 2, 특수문자 = 1이 주어지면 출력은 "D5%t9Bgf" 등의 비밀번호가 되는 거야.]
    """
        },
        {
        "role": "user",
        "content": "pg(길이 = 10, 대문자 = 1, 소문자 = 5, 숫자 = 3, 특수문자 = 1)"
        }
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)

# %%
# 편향

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": """
    Q: 나 방금 굉장한 소식을 들었어!
    A: 긍정
    Q: 우리 급여가 올랐네요!
    A: 긍정
    Q: 나는 오늘 내가 성취한 일에 뿌듯함을 느껴.
    A: 긍정
    Q: 최고의 하루를 보내고 있어!
    A: 긍정
    Q: 이번 주말을 매우 고대하고있어!
    A: 긍정
    Q: 나는 지금 최고의 선물을 받았어!
    A: 긍정
    Q: 나는 지금 매우 행복해.
    A: 긍정
    Q: 이렇게 훌륭한 가족의 일원으로서 축복받았다고 느껴.
    A: 긍정
    Q: 바깥 날씨가 굉장히 흐리네요.
    A: 부정
    Q: 방금 끔찍한 소식을 들었어요.
    A: 부정
    Q: 씁쓸하네요
    A:"""
        }
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": """
    Q: 여기 음식 맛있다!
    A: 긍정
    Q: 난 이 수업이 지겨워.
    A: 부정
    Q: 내가 시험에서 떨어졌다니 믿을 수 없어.
    A: 부정
    Q: 오늘 즐거운 하루였어!
    A: 긍정
    Q: 난 이 일이 싫어.
    A: 부정
    Q: 여기 서비스 엉망이네.
    A: 부정
    Q: 살아가는 데 좌절감을 느껴.
    A: 부정
    Q: 조금도 쉬지 못해.
    A: 부정
    Q: 이 음식 정말 맛없다.
    A: 부정
    Q: 더 이상은 내 상사를 못견디겠어.
    A: 부정
    Q: 무언가가 느껴져.
    A:"""
        }
    ],
    temperature=0,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message.content)

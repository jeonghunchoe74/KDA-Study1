# %% [markdown]
# # 교통사고 유형별 분석
#
# * 사고 유형별 사고건수
#
# ![image.png](attachment:image.png)
#
# * 사고 유형별 사망자수
#
# ![image-2.png](attachment:image-2.png)
#
# * 사고 유형별 중상자수
#
# ![image-3.png](attachment:image-3.png)
#
# *사고 유형별 사망률
#
# 사망률 (%) = (사망자수 ÷ 전체 피해자수) × 100
#
# ![image-4.png](attachment:image-4.png)
#
# *사고 유형별 중상률
#
# 중상률 (%) = (중상자수 ÷ 전체 피해자수) × 100
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### 📌 교통사고 유형별 요약 분석
#
# ####  많이 발생하는 교통사고 유형
# | 구분             | 사고 유형             |
# |------------------|------------------------|
# | **최다 교통사고** | 차대차 - 측면 충돌     |
#
# 차대차 - 측면 충돌:
# 이는 도시나 교차로에서 흔히 발생하는 사고 유형입니다.
# 차량 간 진입 방향 미숙, 신호 위반, 사각지대 등이 주요 원인일 수 있습니다.
#
# 추론:
# → 일상적 교통 흐름 속에서 발생하는 사고가 다수를 차지하며, 운전자의 부주의나 교차로 구조 개선이 필요함을 시사합니다.
#
# ---
#
# ####  사망자, 중상자 수가 많은 교통사고 유형
# | 구분             | 사고 유형               |
# |------------------|--------------------------|
# | **최다 사망자**   | 차대사람 - 횡단 중       |
# | **최다 중상자**   | 차대차 - 측면 충돌       |
#
# 차대사람 - 횡단 중:
# 보행자 사고는 차량 속도와 무방비 상태의 피해자 때문에 사망률이 높습니다.
#
# 추론:
# → 보행자 보호 정책 강화, 횡단보도 앞 일시 정지 의무, 야간 시인성 향상 등이 중요합니다.
#
# 차대차 - 측면 충돌:
# 충돌 시 충격이 운전석이나 조수석에 직접 전달되기 쉽습니다.
#
# 추론:
# → 사고 발생률뿐 아니라 중상 위험성도 높고, 측면 에어백 등 차량 안전 기술 강화도 필요합니다.
#
# ---
#
# ####  사망률, 중상률이 높은 교통사고 유형
# | 구분             | 사고 유형                       |
# |------------------|----------------------------------|
# | **최고 사망률**   | 철길건널목 - 철길건널목 사고     |
# | **최고 중상률**   | 차량 단독 - 도로이탈 추락       |
#
# 철길건널목 사고 :
# 사고 자체는 드물지만, 발생 시 치명률이 매우 높습니다.
#
#  추론:
# → 건널목 자동 차단 시스템 강화, 차량 진입 금지 시스템 설치가 필요합니다.
#
# 차량 단독 - 도로이탈 추락 :
# 차량 혼자 사고 난 경우이지만, 고속 주행 중 이탈로 인해 충격이 큽니다.
#
#  추론:
# → 졸음운전, 음주운전, 과속과 연관 가능성이 높습니다.
# → 도로 안전시설(가드레일, 방호벽)과 운전자 인식 개선이 필요합니다.

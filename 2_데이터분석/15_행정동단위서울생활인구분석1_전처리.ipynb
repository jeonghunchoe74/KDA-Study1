# %%
# ------------------------------------------------
# 라이브러리 import
# ------------------------------------------------

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 데이터 수집
# * 서울 열린 데이터 광장
#     * https://data.seoul.go.kr/dataList/OA-14991/S/1/datasetView.do
#     * 회원가입 및 로그인
#     * 원하는 기간의 데이터 수집 (최근 1년)

# %% [markdown]
# ### 데이터프레임 생성

# %%
# ------------------------------------------------
#  파일경로 패턴을 만족하는 여러 파일 리스트를 불러온다.
# ------------------------------------------------

import glob
file_list = glob.glob('data/LOCAL_PEOPLE_DONG/LOCAL*.csv')
file_list
# Out:
# ['data/LOCAL_PEOPLE_DONG\\LOCAL_PEOPLE_DONG_202404.csv',
#  'data/LOCAL_PEOPLE_DONG\\LOCAL_PEOPLE_DONG_202405.csv',
#  'data/LOCAL_PEOPLE_DONG\\LOCAL_PEOPLE_DONG_202406.csv',
#  'data/LOCAL_PEOPLE_DONG\\LOCAL_PEOPLE_DONG_202407.csv',
#  'data/LOCAL_PEOPLE_DONG\\LOCAL_PEOPLE_DONG_202408.csv',
#  'data/LOCAL_PEOPLE_DONG\\LOCAL_PEOPLE_DONG_202409.csv',
#  'data/LOCAL_PEOPLE_DONG\\LOCAL_PEOPLE_DONG_202410.csv',
#  'data/LOCAL_PEOPLE_DONG\\LOCAL_PEOPLE_DONG_202411.csv',
#  'data/LOCAL_PEOPLE_DONG\\LOCAL_PEOPLE_DONG_202412.csv',
#  'data/LOCAL_PEOPLE_DONG\\LOCAL_PEOPLE_DONG_202501.csv',
#  'data/LOCAL_PEOPLE_DONG\\LOCAL_PEOPLE_DONG_202502.csv',
#  'data/LOCAL_PEOPLE_DONG\\LOCAL_PEOPLE_DONG_202503.csv']

# %%
# ------------------------------------------------
#  파일 리스트의 데이터들을 데이터프레임으로 각각 변환하여
#  데이터프레임 리스트에 추가한다.
# ------------------------------------------------

df_list = []

for file in file_list:
    df_month = pd.read_csv(file,
                     index_col=False,   # 첫번째 컬럼이 인덱스로 자동 지정되는 문제 해결
                     parse_dates = ['기준일ID'],    # datetime 자료형으로 지정할 컬럼
                     dtype={'행정동코드':'str'})    # object 자료형으로 지정할 컬럼
    df_list.append(df_month)

# %%
print('len:', len(df_list))
# Out:
# len: 12

# %%
for df in df_list:
    display(df.head(2))
# Out:
#        기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2024-04-01      0  11440585  16690.3005       489.5882         241.8582
# 1 2024-04-01      0  11290640  17254.8326       265.4667         136.9782
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         321.7900         354.3263         503.1719         615.9802  ...
# 1         936.3727        2108.2782         993.1308         489.6211  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# 0         750.5231         790.1085         839.8785         697.5542
# 1         732.8108         488.7919         414.1525         376.4850
#
#    여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 0         790.7150         636.1098         619.3970         593.8115
# 1         365.5632         455.2348         540.8218         412.3597
#
#    여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         441.4222     1172.2903
# 1         282.3098     1102.3257
#
# [2 rows x 32 columns]
#        기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2024-05-01      0  11110540   3734.7155        68.6866          52.6302
# 1 2024-05-01      0  11530520  17189.2373       895.4136         397.2414
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         341.3469         300.6130          99.0632         128.1989  ...
# 1         520.7046         299.9224         461.0142         604.5068  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# 0          98.0788          87.7881         119.5997         165.6914
# 1         521.4702         705.8152         846.5928         837.0953
#
#    여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 0         186.7774         127.9818         139.0390         127.5617
# 1         812.2302         599.6274         631.9907         554.4330
#
#    여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         119.2118      289.6039
# 1         478.7187      874.7900
#
# [2 rows x 32 columns]
#        기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2024-06-01      0  11110515  15064.5012       526.3518         335.3927
# 1 2024-06-01      0  11110530  12135.6579       211.7727          94.1210
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         578.6529         362.0918         423.3428         373.9520  ...
# 1         238.4391         318.2036         430.8536         502.1432  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# 0         449.5309         572.7480         660.4763         676.4423
# 1         440.2347         530.1791         746.3415         535.8321
#
#    여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 0         840.1702         623.9791         614.9799         544.8446
# 1         710.3134         512.4412         522.6594         413.2529
#
#    여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         327.2646     1154.5795
# 1         286.9292      818.4851
#
# [2 rows x 32 columns]
#        기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2024-07-01      0  11740640  24502.5882       860.6543         444.4424
# 1 2024-07-01      0  11710642  31915.6625       547.0209         240.0195
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         793.6170         546.0153         692.7026         801.0255  ...
# 1         500.5009         707.7086        1443.0077        1904.7495  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# 0         781.5383         881.4770        1185.6678        1062.7676
# 1        1926.5826        2046.3316        1936.9735        1545.9996
#
#    여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 0        1138.4481         960.2420        1029.9286         808.3074
# 1        1249.9123         922.1153         870.8661         787.4879
#
#    여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         708.9547     1895.7347
# 1         603.2885     1605.4546
#
# [2 rows x 32 columns]
#        기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2024-08-01      0  11620645  23991.0304       334.6861         134.0082
# 1 2024-08-01      0  11470530  18702.2208       617.5826         297.2964
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         354.7651        1286.0566        2402.4533        1920.1646  ...
# 1         495.2454         497.1716         733.8611         709.9125  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# 0        2201.8174        1284.5231         904.5559         673.7322
# 1         796.2139         966.4669         993.6816         734.7736
#
#    여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 0         657.6190         593.4499         727.8839         548.4594
# 1         748.7345         704.6347         776.1500         683.1417
#
#    여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         439.2981     1239.3658
# 1         513.8168     1440.5957
#
# [2 rows x 32 columns]
#        기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2024-09-01      0  11110515  14385.0982       464.1945         295.7860
# 1 2024-09-01      0  11110530  10764.6517       259.8465         115.4873
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         544.7136         378.9799         379.4529         377.4148  ...
# 1         191.7147         243.9499         329.0142         352.3773  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# 0         456.7103         451.9655         624.6533         691.8843
# 1         378.0531         469.2400         634.8861         469.3862
#
#    여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 0         771.7197         692.3968         616.8001         501.5347
# 1         623.8038         457.9957         462.8543         366.5094
#
#    여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         323.5667     1032.8741
# 1         263.7653      757.5252
#
# [2 rows x 32 columns]
#        기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2024-10-01      0  11680660  27736.7072      1608.5615        1020.1432
# 1 2024-10-01      0  11620735  27943.6011       367.6497         186.1915
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         963.8123         436.7213         495.7893         508.1934  ...
# 1         633.4226        2441.6645        2671.7548        1806.1475  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# 0         541.3792         653.7765        1301.9191        1487.0351
# 1        2152.9721         986.4603         874.4456         622.5567
#
#    여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 0        1696.0351        1009.8424         932.9972         779.3163
# 1         594.7830         519.6848         617.9238         512.1945
#
#    여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         673.7876     1647.3151
# 1         428.1681     1165.0910
#
# [2 rows x 32 columns]
#        기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2024-11-01      0  11170650  14056.5206       106.5180          57.0386
# 1 2024-11-01      0  11140665  13128.2919       500.4399         244.5584
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         458.0446        1584.1748        1356.1199        1035.6258  ...
# 1         252.0936         300.3381         381.5861         377.3917  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# 0        1021.9879         660.2802         507.3313         412.3809
# 1         461.0259         476.0354         576.9095         509.3889
#
#    여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 0         362.9823         267.8329         278.7752         249.2182
# 1         498.0146         496.4915         580.3465         524.0001
#
#    여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         162.3982      487.4213
# 1         376.0031     1081.7242
#
# [2 rows x 32 columns]
#        기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2024-12-01      0  11110515  14480.0398       492.8819         314.0657
# 1 2024-12-01      0  11110530  11080.8647       244.6505         108.7335
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         522.3721         388.2390         403.4847         375.0892  ...
# 1         207.7857         273.7385         387.6370         387.6365  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# 0         390.6463         488.8212         685.2165         692.0542
# 1         361.0875         490.5173         572.4425         582.2647
#
#    여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 0         794.1584         635.2626         592.4321         538.0315
# 1         585.3554         504.8103         438.1391         403.8694
#
#    여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         311.2327     1075.7885
# 1         252.7272      759.5925
#
# [2 rows x 32 columns]
#        기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2025-01-01      0  11110515  13959.2812       481.4116         306.7564
# 1 2025-01-01      0  11110530  14230.5596       343.2194         152.5419
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         478.2017         357.3834         397.8554         361.7199  ...
# 1         449.6299         551.2311         564.9371         466.4311  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# 0         414.8944         453.7294         628.7862         683.5943
# 1         589.5157         578.3579         608.6689         622.1655
#
#    여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 0         727.1302         618.3577         572.4571         473.0731
# 1         724.4159         641.8814         553.9168         499.1170
#
#    여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         344.2641     1022.5939
# 1         270.3996      873.3966
#
# [2 rows x 32 columns]
#        기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2025-02-01      0  11545690   8387.0890       278.2986         138.7529
# 1 2025-02-01      0  11710642  29386.3979       609.5843         267.4706
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         143.9337         137.2644         218.6926         288.9663  ...
# 1         479.8218         614.6095        1200.5585        1743.2340  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# 0         256.9053         274.0398         401.4684         287.6065
# 1        1521.7525        1647.5727        1801.7835        1485.3905
#
#    여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 0         338.1417         311.6563         335.2920         342.0369
# 1        1183.1304         862.8664         883.1985         753.9192
#
#    여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         293.4793      713.9294
# 1         518.5504     1444.0709
#
# [2 rows x 32 columns]
#        기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2025-03-01      0  11110515  14171.2977       519.8461         331.2471
# 1 2025-03-01      0  11110530  11743.7357       264.1074         117.3811
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         514.3903         366.7717         407.6570         380.0911  ...
# 1         194.8091         281.3030         439.8066         460.4970  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# 0          401.549         461.0957         701.7845         705.5819
# 1          433.445         460.9702         658.8225         581.5576
#
#    여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 0         716.7508         631.7271         600.4593         495.5255
# 1         626.6887         541.7948         486.8450         430.3770
#
#    여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         350.1133     1052.8314
# 1         239.6948      771.5413
#
# [2 rows x 32 columns]

# %%
# -------------------------------------------------------------
# 데이터프레임 리스트의 데이터프레임을 하나의 데이터프레임으로 합친다.
# -------------------------------------------------------------

# %% [markdown]
# ### 데이터프레임 확인

# %%
# Out:
#        기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2024-04-01      0  11440585  16690.3005       489.5882         241.8582
# 1 2024-04-01      0  11290640  17254.8326       265.4667         136.9782
# 2 2024-04-01      0  11260590  24836.1736       575.5669         243.5089
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         321.7900         354.3263         503.1719         615.9802  ...
# 1         936.3727        2108.2782         993.1308         489.6211  ...
# 2         341.0603         962.4267        1496.3834        1380.9687  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# 0         750.5231         790.1085         839.8785         697.5542
# 1         732.8108         488.7919         414.1525         376.4850
# 2        2043.5564        1615.6401        1424.6506         831.8179
#
#    여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 0         790.7150         636.1098         619.3970         593.8115
# 1         365.5632         455.2348         540.8218         412.3597
# 2         784.6880         769.7451         859.3055         761.8320
#
#    여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         441.4222     1172.2903
# 1         282.3098     1102.3257
# 2         514.3764     1342.1258
#
# [3 rows x 32 columns]
#              기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  \
# 3714237 2025-03-31     23  11290810  28737.1532       976.8876
# 3714238 2025-03-31     23  11290630  20935.8562       870.4937
# 3714239 2025-03-31     23  11230750  15365.4322       477.2126
#
#          남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 3714237         496.8428         713.8873        1034.2246        1045.0550
# 3714238         456.1427         533.2160         676.4870         571.4078
# 3714239         288.2674         430.5767         574.9287         468.2913
#
#          남자30세부터34세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  \
# 3714237         953.5513  ...        1284.3664        1042.8606
# 3714238         538.9045  ...         688.4542         681.9016
# 3714239         325.0093  ...         632.7856         481.4357
#
#          여자35세부터39세생활인구수  여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  \
# 3714237        1209.4969         902.2446        1048.1759        1180.0512
# 3714238        1000.2332         834.1445         985.4489         791.2047
# 3714239         605.5899         603.3241         670.8108         652.0026
#
#          여자55세부터59세생활인구수  여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 3714237        1137.0487        1050.4364         838.7798     2406.9983
# 3714238         941.4934         700.7734         573.4601     1373.8368
# 3714239         587.7955         456.9211         385.6993     1199.1022
#
# [3 rows x 32 columns]
#              기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  \
# 3394362 2025-02-28     13  11380560  19416.5829       847.0487
# 2904981 2025-01-11     11  11350560  19861.6087       679.9422
# 316225  2024-05-02      1  11110615  23036.3669       387.4551
#
#          남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 3394362         496.6225         695.6511         615.3179         502.7773
# 2904981         349.7287         557.8031        1327.1869         865.6255
# 316225          122.0749         269.8877        1092.7145        1507.2114
#
#          남자30세부터34세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  \
# 3394362         516.8272  ...         523.7864         512.3921
# 2904981         617.8055  ...         619.8357         527.9674
# 316225         1303.1150  ...        1190.7225         816.7207
#
#          여자35세부터39세생활인구수  여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  \
# 3394362         586.7822         799.0006         825.0015         761.1581
# 2904981         727.9587         766.9933         790.9203         734.4709
# 316225          766.8747         771.4133         755.6862         624.1689
#
#          여자55세부터59세생활인구수  여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 3394362         822.9764         806.1963         605.9481     1849.3065
# 2904981         672.2351         593.7954         502.2614     1436.9259
# 316225          623.5827         560.9149         412.6840     1140.9499
#
# [3 rows x 32 columns]

# %%
# Out:
# shape: (3714240, 32)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315456 entries, 0 to 315455
# Data columns (total 32 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   기준일ID            315456 non-null  datetime64[ns]
#  1   시간대구분            315456 non-null  int64
#  2   행정동코드            315456 non-null  object
#  3   총생활인구수           315456 non-null  float64
#  4   남자0세부터9세생활인구수    315456 non-null  float64
#  5   남자10세부터14세생활인구수  315456 non-null  float64
#  6   남자15세부터19세생활인구수  315456 non-null  float64
#  7   남자20세부터24세생활인구수  315456 non-null  float64
#  8   남자25세부터29세생활인구수  315456 non-null  float64
#  9   남자30세부터34세생활인구수  315456 non-null  float64
#  10  남자35세부터39세생활인구수  315456 non-null  float64
#  11  남자40세부터44세생활인구수  315456 non-null  float64
#  12  남자45세부터49세생활인구수  315456 non-null  float64
#  13  남자50세부터54세생활인구수  315456 non-null  float64
#  14  남자55세부터59세생활인구수  315456 non-null  float64
#  15  남자60세부터64세생활인구수  315456 non-null  float64
#  16  남자65세부터69세생활인구수  315456 non-null  float64
#  17  남자70세이상생활인구수     315456 non-null  float64
#  18  여자0세부터9세생활인구수    315456 non-null  float64
#  19  여자10세부터14세생활인구수  315456 non-null  float64
#  20  여자15세부터19세생활인구수  315456 non-null  float64
#  21  여자20세부터24세생활인구수  315456 non-null  float64
#  22  여자25세부터29세생활인구수  315456 non-null  float64
#  23  여자30세부터34세생활인구수  315456 non-null  float64
#  24  여자35세부터39세생활인구수  315456 non-null  float64
#  25  여자40세부터44세생활인구수  315456 non-null  float64
#  26  여자45세부터49세생활인구수  315456 non-null  float64
#  27  여자50세부터54세생활인구수  315456 non-null  float64
#  28  여자55세부터59세생활인구수  315456 non-null  float64
#  29  여자60세부터64세생활인구수  315456 non-null  float64
#  30  여자65세부터69세생활인구수  315456 non-null  float64
#  31  여자70세이상생활인구수     315456 non-null  float64
# dtypes: datetime64[ns](1), float64(29), int64(1), object(1)
# memory usage: 77.0+ MB

# %%
# Out:
# 기준일ID              datetime64[ns]
# 시간대구분                       int64
# 행정동코드                      object
# 총생활인구수                    float64
# 남자0세부터9세생활인구수             float64
# 남자10세부터14세생활인구수           float64
# 남자15세부터19세생활인구수           float64
# 남자20세부터24세생활인구수           float64
# 남자25세부터29세생활인구수           float64
# 남자30세부터34세생활인구수           float64
# 남자35세부터39세생활인구수           float64
# 남자40세부터44세생활인구수           float64
# 남자45세부터49세생활인구수           float64
# 남자50세부터54세생활인구수           float64
# 남자55세부터59세생활인구수           float64
# 남자60세부터64세생활인구수           float64
# 남자65세부터69세생활인구수           float64
# 남자70세이상생활인구수              float64
# 여자0세부터9세생활인구수             float64
# 여자10세부터14세생활인구수           float64
# 여자15세부터19세생활인구수           float64
# 여자20세부터24세생활인구수           float64
# 여자25세부터29세생활인구수           float64
# 여자30세부터34세생활인구수           float64
# 여자35세부터39세생활인구수           float64
# 여자40세부터44세생활인구수           float64
# 여자45세부터49세생활인구수           float64
# 여자50세부터54세생활인구수           float64
# 여자55세부터59세생활인구수           float64
# 여자60세부터64세생활인구수           float64
# 여자65세부터69세생활인구수           float64
# 여자70세이상생활인구수              float64
# dtype: object

# %% [markdown]
# ### 월, 일 컬럼 추가

# %%
# ---------------------------------------
# 월, 일 컬럼 추가
# ---------------------------------------
# Out:
#              기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  \
# 3104790 2025-01-31      2  11560650  16100.0738       619.8246
# 2384844 2024-11-21      8  11530540  52007.8472       827.9501
# 2213469 2024-11-04     12  11380640  11676.3691       581.8701
#
#          남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 3104790         290.8964         335.6053         367.3355         552.8006
# 2384844         341.9035         369.6152        1130.2511        3068.4344
# 2213469         345.3543         186.4182         341.9631         347.4319
#
#          남자30세부터34세생활인구수  ...  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# 3104790         589.0555  ...         724.1026         561.3710
# 2384844        3365.1435  ...        3266.5284        2454.7652
# 2213469         349.5547  ...         484.7298         401.6704
#
#          여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  \
# 3104790         594.0615         653.9703         699.4865         598.0666
# 2384844        2437.3691        1776.2161        1402.8885         993.6191
# 2213469         492.1743         486.8837         427.8751         451.8051
#
#          여자65세부터69세생활인구수  여자70세이상생활인구수   월   일
# 3104790         459.8929     1087.7368   1  31
# 2384844         658.1238     1426.8037  11  21
# 2213469         334.0325      780.0268  11   4
#
# [3 rows x 34 columns]

# %% [markdown]
# ### 요일 컬럼 추가
# * `dt.dayofweek` : 요일번호(0:Mon~)
# * `dt.day_name()` : 요일명 full name (Monday, Tuesday, ...)
# * `dt.day_name().str[:3]` : 요일명 약자 (Mon, Tue, ...)
# * `dt.strftime('%A')` : 요일명 full name (Monday, Tuesday, ...)
# * `dt.strftime('%a')`  : 요일명 약자 (Mon, Tue, ...)

# %%
# ---------------------------------------
# 요일 컬럼 추가
#   day_name()
# ---------------------------------------

# %%
# Out:
#              기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  \
# 753842  2024-06-14      1  11710590  19903.6388       878.4903
# 1486865 2024-08-25      2  11590651  13237.0701       526.6783
# 1472619 2024-08-23     17  11200660  28815.1704       581.5439
#
#          남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 753842          480.3038         576.5303         449.6033         552.7917
# 1486865         244.6379         316.8674         358.0874         518.1230
# 1472619         262.3052         467.5498         972.9425        1601.9998
#
#          남자30세부터34세생활인구수  ...  여자40세부터44세생활인구수  여자45세부터49세생활인구수  \
# 753842          617.7405  ...         923.4817         920.4314
# 1486865         529.6112  ...         560.9692         568.2125
# 1472619        1578.5940  ...        1059.9712         996.7863
#
#          여자50세부터54세생활인구수  여자55세부터59세생활인구수  여자60세부터64세생활인구수  여자65세부터69세생활인구수  \
# 753842          776.9747         818.7008         687.3495         566.5064
# 1486865         498.6444         517.1021         462.0445         328.4206
# 1472619         820.7552         712.0589         493.3218         303.2892
#
#          여자70세이상생활인구수  월   일   요일
# 753842      1244.4208  6  14  Fri
# 1486865      949.2582  8  25  Sun
# 1472619      833.0188  8  23  Fri
#
# [3 rows x 35 columns]

# %% [markdown]
# ### 시도명, 시군구명, 행정동명 추가

# %% [markdown]
# #### [참고] 법정동과 행정동
#     * 법정동과 행정동은 우리나라의 행정구역을 구분하는 두 가지 서로 다른 체계입니다.
#
# ---
#
# * 법정동
#     * 법률로 지정된 공식 행정구역
#     * 1914년 행정구역 통폐합 때 만들어져 현재까지 유지
#     * 국토교통부에서 관리
#     * 등기부등본, 신분증 등 모든 법적 문서의 주소 표기에 사용
#     * 부동산 규제 등 법적 업무의 기준
#     * 명칭 변동이 거의 없음
#
# ---
#
# * 행정동
#     * 행정 편의를 위해 설정된 관리 구역
#     * 행정안전부에서 관리
#     * 인구수와 행정 수요에 따라 수시로 조정 가능
#     * **행정동 코드는 자주 변경되므로, 해당 데이터의 행정동 코드 기준 시점을 확인하여야 함.**
#     * **생활인구 데이터는 데이터 일관성 유지를 위해 2016년 집계구, 행정동 코드를 사용하고 있음**
#
# ---
# * 법정동과 행정동의 관계
#     * 두 구역은 N:M 관계
#     * 하나의 법정동이 여러 행정동으로 나뉠 수 있음
#     * 여러 법정동이 하나의 행정동으로 통합될 수 있음
#     * 일부 지역은 법정동과 행정동이 일치하기도 함
#     * 예를 들어, 서울 중구의 경우 법정동은 87개지만 행정동은 17개만 존재
#     * 반대로 송파구 잠실동(법정동)은 잠실본동, 잠실2동, 잠실3동, 잠실7동이라는 4개의 행정동으로 나뉨

# %% [markdown]
# #### 행정동코드 매핑정보
# * 행정구역코드정보 파일 다운로드
#     *  https://data.seoul.go.kr/dataVisual/seoul/seoulLivingPopulation.do

# %%
# -----------------------------------------------
# 행정동코드와 행정동명 매핑을 위한 데이터프레임 생성
#   df_region
#   read_excel
#       - sheel_name
#       - header
#       - skiprows
#       - usecols
#       - dtype
# -----------------------------------------------

file_path = 'data/LOCAL_PEOPLE_DONG/행정동코드_매핑정보_20241218.xlsx'
# Out:
#      행자부행정동코드 시도명 시군구명  행정동명
# 0    11110530  서울  종로구   사직동
# 1    11110540  서울  종로구   삼청동
# 2    11110550  서울  종로구   부암동
# 3    11110560  서울  종로구   평창동
# 4    11110570  서울  종로구   무악동
# ..        ...  ..  ...   ...
# 419  11740690  서울  강동구  둔촌1동
# 420  11740700  서울  강동구  둔촌2동
# 421  11740570  서울  강동구  암사1동
# 422  11740610  서울  강동구  천호2동
# 423  11740685  서울  강동구    길동
#
# [424 rows x 4 columns]

# %%
# -----------------------------------------------
# 일관성을 위해 컬럼명 변경
#   행자부행정동코드 -> 행정동코드
# -----------------------------------------------

# %%
# Out:
#       행정동코드 시도명 시군구명 행정동명
# 0  11110530  서울  종로구  사직동
# 1  11110540  서울  종로구  삼청동
# 2  11110550  서울  종로구  부암동
# 3  11110560  서울  종로구  평창동
# 4  11110570  서울  종로구  무악동

# %%
# -----------------------------------------------
# 시도명, 시군구명, 행정동명 추가
# -----------------------------------------------

# %%
# Out:
# 시도명     0
# 시군구명    0
# 행정동명    0
# dtype: int64

# %% [markdown]
# ### 행정동코드 자리수 맞추기
# * 행정동 코드 길이를 10자리로 만들기
# * geojson의 행정동코드 자리수와 맞추기 위함

# %%
# Out:
# 0          8
# 1          8
# 2          8
# 3          8
# 4          8
#           ..
# 3714235    8
# 3714236    8
# 3714237    8
# 3714238    8
# 3714239    8
# Name: 행정동코드, Length: 3714240, dtype: int64

# %%
# -----------------------------------------------
# 행정동코드의 길이를 10자리로 만들기
# -----------------------------------------------

# %%
# Out:
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
#            ..
# 3714235    10
# 3714236    10
# 3714237    10
# 3714238    10
# 3714239    10
# Name: 행정동코드, Length: 3714240, dtype: int64

# %% [markdown]
# ### 컬럼명 정리

# %%
# -------------------------------------
# 컬럼명 확인 및 변경 계획
# -------------------------------------

df_all.columns

# 컬럼명 변경 계획 
# >>>>> 4번째 컬럼 ~ -5번째 컬럼의 '생활인구수' 제거
# >>>>> replace("생활인구수","")
# Out:
# Index(['기준일ID', '시간대구분', '행정동코드', '총생활인구수', '남자0세부터9세생활인구수', '남자10세부터14세생활인구수',
#        '남자15세부터19세생활인구수', '남자20세부터24세생활인구수', '남자25세부터29세생활인구수',
#        '남자30세부터34세생활인구수', '남자35세부터39세생활인구수', '남자40세부터44세생활인구수',
#        '남자45세부터49세생활인구수', '남자50세부터54세생활인구수', '남자55세부터59세생활인구수',
#        '남자60세부터64세생활인구수', '남자65세부터69세생활인구수', '남자70세이상생활인구수', '여자0세부터9세생활인구수',
#        '여자10세부터14세생활인구수', '여자15세부터19세생활인구수', '여자20세부터24세생활인구수',
#        '여자25세부터29세생활인구수', '여자30세부터34세생활인구수', '여자35세부터39세생활인구수',
#        '여자40세부터44세생활인구수', '여자45세부터49세생활인구수', '여자50세부터54세생활인구수',
#        '여자55세부터59세생활인구수', '여자60세부터64세생활인구수', '여자65세부터69세생활인구수', '여자70세이상생활인구수',
#        '월', '일', '요일', '시도명', '시군구명', '행정동명'],
#       dtype='object')

# %%
# -------------------------------------
# 변경할 컬럼명 만들기
#   - new_names
#       replace("생활인구수","") 
# -------------------------------------

# %%
# -------------------------------------
# 컬럼명 변경
# -------------------------------------

# %%
# Out:
#        기준일ID  시간대구분       행정동코드           총   남자0세부터9세  남자10세부터14세  \
# 0 2024-04-01      0  1144058500  16690.3005   489.5882    241.8582
# 1 2024-04-01      0  1129064000  17254.8326   265.4667    136.9782
# 2 2024-04-01      0  1126059000  24836.1736   575.5669    243.5089
# 3 2024-04-01      0  1153054000  26975.9704   677.5741    279.8057
# 4 2024-04-01      0  1150054000  49512.7524  1540.8540    551.2752
#
#    남자15세부터19세  남자20세부터24세  남자25세부터29세  남자30세부터34세  ...  여자55세부터59세  \
# 0    321.7900    354.3263    503.1719    615.9802  ...    619.3970
# 1    936.3727   2108.2782    993.1308    489.6211  ...    540.8218
# 2    341.0603    962.4267   1496.3834   1380.9687  ...    859.3055
# 3    332.3631    700.5115   1785.0252   1670.2933  ...    823.7957
# 4    689.7894   1323.5019   2398.6313   2653.4434  ...   1928.3318
#
#    여자60세부터64세  여자65세부터69세    여자70세이상  월  일   요일  시도명  시군구명  행정동명
# 0    593.8115    441.4222  1172.2903  4  1  Mon   서울   마포구   도화동
# 1    412.3597    282.3098  1102.3257  4  1  Mon   서울   성북구  정릉3동
# 2    761.8320    514.3764  1342.1258  4  1  Mon   서울   중랑구  상봉2동
# 3    799.9066    553.7243  1267.0419  4  1  Mon   서울   구로구  구로3동
# 4   1546.4568   1473.8741  3217.3606  4  1  Mon   서울   강서구  화곡1동
#
# [5 rows x 38 columns]

# %% [markdown]
# ### 컬럼 순서 정리

# %%
# Out:
# Index(['기준일ID', '시간대구분', '행정동코드', '총', '남자0세부터9세', '남자10세부터14세', '남자15세부터19세',
#        '남자20세부터24세', '남자25세부터29세', '남자30세부터34세', '남자35세부터39세', '남자40세부터44세',
#        '남자45세부터49세', '남자50세부터54세', '남자55세부터59세', '남자60세부터64세', '남자65세부터69세',
#        '남자70세이상', '여자0세부터9세', '여자10세부터14세', '여자15세부터19세', '여자20세부터24세',
#        '여자25세부터29세', '여자30세부터34세', '여자35세부터39세', '여자40세부터44세', '여자45세부터49세',
#        '여자50세부터54세', '여자55세부터59세', '여자60세부터64세', '여자65세부터69세', '여자70세이상', '월',
#        '일', '요일', '시도명', '시군구명', '행정동명'],
#       dtype='object')

# %%
cols = ['기준일ID', '월', '일','요일', '시간대구분', '행정동코드', '시도명', '시군구명', '행정동명'\
        , '총', '남자0세부터9세', '남자10세부터14세'
        , '남자15세부터19세', '남자20세부터24세', '남자25세부터29세', '남자30세부터34세', '남자35세부터39세'\
        , '남자40세부터44세', '남자45세부터49세', '남자50세부터54세', '남자55세부터59세', '남자60세부터64세'\
        , '남자65세부터69세', '남자70세이상', '여자0세부터9세', '여자10세부터14세', '여자15세부터19세'\
        , '여자20세부터24세', '여자25세부터29세', '여자30세부터34세', '여자35세부터39세', '여자40세부터44세'\
        , '여자45세부터49세', '여자50세부터54세', '여자55세부터59세', '여자60세부터64세', '여자65세부터69세'\
        , '여자70세이상']

# %%
# Out:
#        기준일ID  월  일   요일  시간대구분       행정동코드 시도명 시군구명  행정동명           총  ...  \
# 0 2024-04-01  4  1  Mon      0  1144058500  서울  마포구   도화동  16690.3005  ...
# 1 2024-04-01  4  1  Mon      0  1129064000  서울  성북구  정릉3동  17254.8326  ...
# 2 2024-04-01  4  1  Mon      0  1126059000  서울  중랑구  상봉2동  24836.1736  ...
# 3 2024-04-01  4  1  Mon      0  1153054000  서울  구로구  구로3동  26975.9704  ...
# 4 2024-04-01  4  1  Mon      0  1150054000  서울  강서구  화곡1동  49512.7524  ...
#
#    여자25세부터29세  여자30세부터34세  여자35세부터39세  여자40세부터44세  여자45세부터49세  여자50세부터54세  \
# 0    750.5231    790.1085    839.8785    697.5542    790.7150    636.1098
# 1    732.8108    488.7919    414.1525    376.4850    365.5632    455.2348
# 2   2043.5564   1615.6401   1424.6506    831.8179    784.6880    769.7451
# 3   1510.6376   1321.0909   1352.3565   1060.4784   1042.7210    782.7908
# 4   3170.3796   2592.4259   2458.9594   1956.3342   1870.8576   1692.5864
#
#    여자55세부터59세  여자60세부터64세  여자65세부터69세    여자70세이상
# 0    619.3970    593.8115    441.4222  1172.2903
# 1    540.8218    412.3597    282.3098  1102.3257
# 2    859.3055    761.8320    514.3764  1342.1258
# 3    823.7957    799.9066    553.7243  1267.0419
# 4   1928.3318   1546.4568   1473.8741  3217.3606
#
# [5 rows x 38 columns]

# %% [markdown]
# ### 파일로 다운로드
# * 전처리 완료된 데이터프레임을 csv파일로 다운로드

# %%
# ------------------
# 파일로 다운로드
# ------------------

# %%
# ------------------
# 확인
# ------------------
# Out:
#          Unnamed: 0       기준일ID  월   일   요일  시간대구분       행정동코드 시도명  시군구명  \
# 0                 0  2024-04-01  4   1  Mon      0  1144058500  서울   마포구
# 1                 1  2024-04-01  4   1  Mon      0  1129064000  서울   성북구
# 2                 2  2024-04-01  4   1  Mon      0  1126059000  서울   중랑구
# 3                 3  2024-04-01  4   1  Mon      0  1153054000  서울   구로구
# 4                 4  2024-04-01  4   1  Mon      0  1150054000  서울   강서구
# ...             ...         ... ..  ..  ...    ...         ...  ..   ...
# 3714235     3714235  2025-03-31  3  31  Mon     23  1126069000  서울   중랑구
# 3714236     3714236  2025-03-31  3  31  Mon     23  1120053500  서울   성동구
# 3714237     3714237  2025-03-31  3  31  Mon     23  1129081000  서울   성북구
# 3714238     3714238  2025-03-31  3  31  Mon     23  1129063000  서울   성북구
# 3714239     3714239  2025-03-31  3  31  Mon     23  1123075000  서울  동대문구
#
#            행정동명  ...  여자25세부터29세  여자30세부터34세  여자35세부터39세  여자40세부터44세  \
# 0           도화동  ...    750.5231    790.1085    839.8785    697.5542
# 1          정릉3동  ...    732.8108    488.7919    414.1525    376.4850
# 2          상봉2동  ...   2043.5564   1615.6401   1424.6506    831.8179
# 3          구로3동  ...   1510.6376   1321.0909   1352.3565   1060.4784
# 4          화곡1동  ...   3170.3796   2592.4259   2458.9594   1956.3342
# ...         ...  ...         ...         ...         ...         ...
# 3714235    신내2동  ...    469.8132    508.6383    708.5668    656.3241
# 3714236  왕십리도선동  ...   1678.0251   1516.7660   1704.5064   1440.1012
# 3714237     석관동  ...   1284.3664   1042.8606   1209.4969    902.2446
# 3714238    정릉2동  ...    688.4542    681.9016   1000.2332    834.1445
# 3714239    이문2동  ...    632.7856    481.4357    605.5899    603.3241
#
#          여자45세부터49세  여자50세부터54세  여자55세부터59세  여자60세부터64세  여자65세부터69세    여자70세이상
# 0          790.7150    636.1098    619.3970    593.8115    441.4222  1172.2903
# 1          365.5632    455.2348    540.8218    412.3597    282.3098  1102.3257
# 2          784.6880    769.7451    859.3055    761.8320    514.3764  1342.1258
# 3         1042.7210    782.7908    823.7957    799.9066    553.7243  1267.0419
# 4         1870.8576   1692.5864   1928.3318   1546.4568   1473.8741  3217.3606
# ...             ...         ...         ...         ...         ...        ...
# 3714235    653.1125    602.4664    794.4989    702.7255    514.0592  1310.8696
# 3714236   1247.8767   1079.9946   1273.9977    957.8658    670.4120  1852.5813
# 3714237   1048.1759   1180.0512   1137.0487   1050.4364    838.7798  2406.9983
# 3714238    985.4489    791.2047    941.4934    700.7734    573.4601  1373.8368
# 3714239    670.8108    652.0026    587.7955    456.9211    385.6993  1199.1022
#
# [3714240 rows x 39 columns]
